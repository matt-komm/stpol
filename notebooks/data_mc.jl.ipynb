# %%
include("../src/fraction_fit/hists.jl");
# Out:
# Warning: using FS.rename in module DataFrames conflicts with an existing identifier.

# %%
using HDF5, JLD, DataFrames, DataArrays, PyPlot;

# %%
#const BASE="/Users/joosep/Documents/stpol/"
const BASE="/home/joosep/singletop/stpol2/src/skim";

# %%
fi = jldopen("$BASE/skim_nov29_5/merged/skim_nov29_5.jld.1T", "r"; mmaparrays=false);

# %%
tic()
indata = DataFrame(read(fi, "df"));
toc();
# Out:
# Warning: imported binding for transpose overwritten in module __anon__
# Warning: imported binding for transpose overwritten in module __anon__
# Warning: imported binding for transpose overwritten in module __anon__
# elapsed time: 38
# .979985693 seconds

# %%
tic();
inds = perform_selection(indata);
toc();
# Out:
# elapsed time:
# 5.083332906 seconds

# %%
indata[inds[:data_mu] .* inds[:aiso], :totweight] = 1.0;
indata[inds[:data_ele] .* inds[:aiso], :totweight] = 1.0;
indata[inds[:mu] .* inds[:aiso], :totweight] = 8 .* indata[inds[:mu] .* inds[:aiso], :totweight];
indata[inds[:ele] .* inds[:aiso], :totweight] = 4 .* indata[inds[:ele] .* inds[:aiso], :totweight];

# %%
yields(
indata[inds[:njets](2) .* inds[:ntags](1) .* inds[:dr] .* inds[:mtw] .* inds[:mu] .* inds[:hlt](:mu) .* inds[:ljet_rms], :],
sample_is("data_mu"); weight_ex=:(xsweight .* totweight)
)
# Out:
# 11x3 DataFrame:
#                 ds     uy       y
# [1,]        "DATA"  72931 72931.0
# [2,]          "MC" 562889 66772.1
# [3,]     "diboson"   6392  497.01
# [4,]      "dyjets"    321 1109.29
# [5,]       "gjets"      0     0.0
# [6,]         "qcd"   2145 1262.97
# [7,]       "schan"   2078 575.888
# [8,]       "tchan" 105002 10677.1
# [9,]      "ttjets" 422526 32017.0
# [10,]     "twchan"   8802 3909.71
# [11,]      "wjets"  15623 16723.2

# %%
yields(
indata[inds[:njets](2) .* inds[:ntags](1) .* inds[:dr] .* inds[:met] .* inds[:ele] .* inds[:hlt](:ele) .* inds[:ljet_rms], :],
sample_is("data_ele"); weight_ex=:(xsweight .* totweight)
)
# Out:
# 11x3 DataFrame:
#                 ds     uy       y
# [1,]        "DATA"  45377 45377.0
# [2,]          "MC" 409785 43585.8
# [3,]     "diboson"   3949 318.299
# [4,]      "dyjets"    139 432.816
# [5,]       "gjets"     38 118.559
# [6,]         "qcd"   1276 1202.54
# [7,]       "schan"   1207 331.035
# [8,]       "tchan"  60814 6090.66
# [9,]      "ttjets" 328001 24109.2
# [10,]     "twchan"   5815  2563.7
# [11,]      "wjets"   8546 8419.01

# %%
tic()
ret = channel_comparison(
    indata, inds[:njets](2) .* inds[:ntags](1) .* inds[:dr],
    :C, linspace(0, 1, 30), "C",
    {:mu=>inds[:hlt](:mu) .* inds[:mu] .* inds[:mtw], :ele=>inds[:hlt](:ele) .* inds[:ele] .* inds[:met]};
)
toc()
# Out:
# 11x6 DataFrame:
#                 ds     uy       y      ds_1   uy_1     y_1
# [1,]        "DATA"  89678 89678.0    "DATA"  55794 55794.0
# [2,]          "MC" 691059 81208.0      "MC" 506856 53303.4
# [3,]     "diboson"   8306 631.434 "diboson"   5008 394.886
# [4,]      "dyjets"    412  1409.0  "dyjets"    172 553.713
.6896551724137931,0.7241379310344828,0.7586206896551724,0.7931034482758621,0.8275862068965517,0.8620689655172413,0.89655172413793 ...

# %%
to_df(mergehists(ret[:hists][:mu]))
# Out:
# DataFrame with 30 rows, 15 columns
# Columns:
#
# bins__qcd          30 non-null values
# errs__qcd          30 non-null values
# edges__qcd         30 non-null values
# bins__wzjets       30 non-null values
# errs__wzjets       30 non-null values
# edges__wzjets      30 non-null values
# bins__ttjets       30 non-null values
# errs__ttjets       30 non-null values
# edges__ttjets      30 non-null values
# bins__DATA         30 non-null values
# errs__DATA         30 non-null values
# edges__DATA        30 non-null values
# bins__tchan        30 non-null values
# errs__tchan        30 non-null values
# edges__tchan       30 non-null values

# %%
tic()
channel_comparison(
    indata, inds[:njets](2) .* inds[:ntags](1) .* inds[:dr],
    :bdt_sig_bg, linspace(-1, 1, 30), "BDT output",
    {:mu=>inds[:hlt](:mu) .* inds[:mu] .* inds[:mtw], :ele=>inds[:hlt](:ele) .* inds[:ele] .* inds[:met]}
)
toc()
# Out:
# no method yields(Dict{Any,Any})
# while loading In[4], in expression starting on line 2
#  in getindex at /home/joosep/.julia/PyCall/src/PyCall.jl:566
#  in pysequence_query at /home/joosep/.julia/PyCall/src/conversions.jl:741
#  in pytype_query at /home/joosep/.julia/PyCall/src/conversions.jl:754
#  in convert at /home/joosep/.julia/PyCall/src/conversions.jl:803
#  in pycall at /home/joosep/.julia/PyCall/src/PyCall.jl:728
#  in fn at /home/joosep/.julia/PyCall/src/conversions.jl:181
#  in anonymous at /home/joosep/.julia/PyPlot/src/PyPlot.jl:188

# %%
tic()
channel_comparison(
    indata, inds[:njets](2) .* inds[:ntags](1) .* inds[:dr],
    :met, linspace(0, 150, 30), "MET",
    {:mu=>inds[:hlt](:mu) .* inds[:mu], :ele=>inds[:hlt](:ele) .* inds[:ele]}
)
toc()
# Out:
# no method yields(Dict{Any,Any})
# while loading In[5], in expression starting on line 2
#  in getindex at /home/joosep/.julia/PyCall/src/PyCall.jl:566
#  in pysequence_query at /home/joosep/.julia/PyCall/src/conversions.jl:741
#  in pytype_query at /home/joosep/.julia/PyCall/src/conversions.jl:754
#  in convert at /home/joosep/.julia/PyCall/src/conversions.jl:803
#  in pycall at /home/joosep/.julia/PyCall/src/PyCall.jl:728
#  in fn at /home/joosep/.julia/PyCall/src/conversions.jl:181
#  in anonymous at /home/joosep/.julia/PyPlot/src/PyPlot.jl:188

# %%
tic()
channel_comparison(
    indata, inds[:njets](2) .* inds[:ntags](1) .* inds[:dr],
    :top_mass, linspace(80, 300, 30), "top mass",
    {:mu=>inds[:hlt](:mu) .* inds[:mu] .* inds[:mtw], :ele=>inds[:hlt](:ele) .* inds[:ele] .* inds[:met]}
)
toc()
# Out:
# no method yields(Dict{Any,Any})
# while loading In[6], in expression starting on line 2
#  in getindex at /home/joosep/.julia/PyCall/src/PyCall.jl:566
#  in pysequence_query at /home/joosep/.julia/PyCall/src/conversions.jl:741
#  in pytype_query at /home/joosep/.julia/PyCall/src/conversions.jl:754
#  in convert at /home/joosep/.julia/PyCall/src/conversions.jl:803
#  in pycall at /home/joosep/.julia/PyCall/src/PyCall.jl:728
#  in fn at /home/joosep/.julia/PyCall/src/conversions.jl:181
#  in anonymous at /home/joosep/.julia/PyPlot/src/PyPlot.jl:188

# %%
include("../src/fraction_fit/hists.jl");
# Out:
# Warning: using FS.rename in module DataFrames conflicts with an existing identifier.

# %%
cd("$BASE/notebooks")

# %%
const OFDIR = "$BASE/src/fraction_fit/$FITDIR";
run(`rm -rf $OFDIR`);
mkpath(OFDIR)
println(OFDIR)
# Out:
# Warning: imported binding for transpose overwritten in module __anon__
# Warning: imported binding for transpose overwritten in module __anon__
# Warning: imported binding for transpose overwritten in module __anon__
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits

# %%
results = Dict();

# %%
INDIR="$BASE/src/fraction_fit/results/dec19_1/hists";

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t/mu")
cp("$INDIR/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t/mu/bdt.csv")
fr1 = run_fit("$OFDIR/2j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t/ele")
cp("$INDIR/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t/ele/bdt.csv")
fr2 = run_fit("$OFDIR/2j1t/ele");
results[:r1__2j1t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t/mu/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t/mu/results.json
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t/ele/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t.pdf")
savefig("$OFDIR/fit_corr__2j1t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b6abd50>)

# %%
run(`rm -rf $OFDIR/3j1t`)
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j1t/mu")
cp("$INDIR/bdt__3j1t_hmet.csv.mu", "$OFDIR/3j1t/mu/bdt.csv")
fr1 = run_fit("$OFDIR/3j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j1t/ele")
cp("$INDIR/bdt__3j1t_hmet.csv.ele", "$OFDIR/3j1t/ele/bdt.csv")
fr2 = run_fit("$OFDIR/3j1t/ele");
results[:r1__3j1t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j1t/mu/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j1t/mu/results.json
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j1t/ele/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j1t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J1T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__3j1t.pdf")
savefig("$OFDIR/fit_corr__3j1t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b5d0790>)

# %%
run(`rm -rf $OFDIR/3j2t`)
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j2t/mu")
cp("$INDIR/bdt__3j2t_hmet.csv.mu", "$OFDIR/3j2t/mu/bdt.csv")
fr1 = run_fit("$OFDIR/3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j2t/ele")
cp("$INDIR/bdt__3j2t_hmet.csv.ele", "$OFDIR/3j2t/ele/bdt.csv")
fr2 = run_fit("$OFDIR/3j2t/ele");
results[:r1__3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j2t/mu/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j2t/mu/results.json
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j2t/ele/bdt.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/3j2t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__3j2t.pdf")
savefig("$OFDIR/fit_corr__3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ae77a10>)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf $OFDIR/2j1t_3j2t`)
mkpath("$OFDIR/2j1t_3j2t/mu")
cp("$INDIR/bdt__3j2t_hmet.csv.mu", "$OFDIR/2j1t_3j2t/mu/bdt_3j2t.csv")
cp("$INDIR/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t_3j2t/mu/bdt_2j1t.csv")
fr1 = run_fit("$OFDIR/2j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t_3j2t/ele")
cp("$INDIR/bdt__3j2t_hmet.csv.ele", "$OFDIR/2j1t_3j2t/ele/bdt_3j2t.csv")
cp("$INDIR/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t_3j2t/ele/bdt_2j1t.csv")
fr2 = run_fit("$OFDIR/2j1t_3j2t/ele");
results[:r2__2j1t_3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/mu/bdt_2j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/mu/bdt_3j2t.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/mu/results.json
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/ele/bdt_2j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/ele/bdt_3j2t.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j2t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t_3j2t.pdf")
savefig("$OFDIR/fit_corr__2j1t_3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1182f0450>)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf $OFDIR/2j1t_3j1t_3j2t`)
mkpath("$OFDIR/2j1t_3j1t_3j2t/mu")
cp("$INDIR/bdt__3j2t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j2t.csv")
cp("$INDIR/bdt__3j1t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j1t.csv")
cp("$INDIR/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_2j1t.csv")
fr1 = run_fit("$OFDIR/2j1t_3j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t_3j1t_3j2t/ele")
cp("$INDIR/bdt__3j2t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_3j2t.csv")
cp("$INDIR/bdt__3j1t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_3j1t.csv")
cp("$INDIR/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_2j1t.csv")
fr2 = run_fit("$OFDIR/2j1t_3j1t_3j2t/ele");
results[:r3__2j1t_3j1t_3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/mu/bdt_2j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/mu/bdt_3j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/mu/bdt_3j2t.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/mu/results.json
# model files: /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/ele/bdt_2j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/ele/bdt_3j1t.csv,/Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/ele/bdt_3j2t.csv
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits/2j1t_3j1t_3j2t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J1T, 3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t_3j1t_3j2t.pdf")
savefig("$OFDIR/fit_corr__2j1t_3j1t_3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b68c190>)

# %%
totd = DataFrame()
for (k, v) in results
  for (lep, fr) in v
    d = todf(fr)
    d["region"] = split(string(k), "__")[2]
    d["lepton"] = string(lep)
    totd = vcat(totd, d)
  end
end
writetable("$BASE/src/fraction_fit/$FITDIR/fits.mu.csv", totd[totd["lepton"] .== "mu", :])
writetable("$BASE/src/fraction_fit/$FITDIR/fits.ele.csv", totd[totd["lepton"] .== "ele", :])

# %%
prk = ["W+Jets, \$ \\gamma \$-jets,\nZ+jets, diboson", "\$ t \\bar{t} \$, tW, s, QCD", "Data", "t-channel"];

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_2j1t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_2j1t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](VARS[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")
a2[:set_xlabel](VARS[:bdt_sig_bg])

leg = a2[:legend](r, prk, fancybox=true,loc="best")
leg[:get_frame]()[:set_alpha](0.5)

a1[:grid]()
a2[:grid]()
suptitle("2J1T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__2j1t.pdf")
savefig("$OFDIR/fit_shape__2j1t.png")
# Out:
# bins__wzjets
# errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b975750>)

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j1t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_3j1t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](VARS[:bdt_sig_bg])
a2[:set_xlabel](VARS[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")

leg = a2[:legend](r, prk, fancybox=true)
leg[:get_frame]()[:set_alpha](0.5)

#a2[:set_ylim](0, 0.12)
a1[:grid]()
a2[:grid]()
suptitle("3J1T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__3j1t.pdf")
savefig("$OFDIR/fit_shape__3j1t.png")
# Out:
# bins__wzjets
# errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x11c683c50>)

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j2t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_3j2t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](VARS[:bdt_sig_bg])
a2[:set_xlabel](VARS[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")
leg = a2[:legend](r, prk, fancybox=true)
leg[:get_frame]()[:set_alpha](0.5)
a1[:grid]()
a2[:grid]()
suptitle("3J2T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__3j2t.pdf")
savefig("$OFDIR/fit_shape__3j2t.png")
# Out:
# bins__wzjets
#  errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ae7b1d0>)

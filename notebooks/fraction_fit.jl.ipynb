# %%
include("../src/fraction_fit/hists.jl");

# %%
cd("$BASE/notebooks")

# %%
#run(`rm -rf ../src/fraction_fit/fits/`)
const OFDIR = "$BASE/src/fraction_fit/$FITDIR";
mkpath(OFDIR)
println(OFDIR)
# Out:
# ...
# /Users/joosep/Documents/stpol//src/fraction_fit/output/fits

# %%
results = Dict();

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t/mu")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t/mu/bdt.csv")
fr1 = run_fit("fits/2j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t/ele")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t/ele/bdt.csv")
fr2 = run_fit("fits/2j1t/ele");

results[:r1__2j1t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/2j1t/mu/bdt_2j1t_hmet.csv.mu
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/2j1t/mu/results.json
# model files: fits/2j1t/ele/bdt_2j1t_hmet.csv.ele
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/2j1t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t.pdf")
savefig("$OFDIR/fit_corr__2j1t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10fee3050>)

# %%
run(`rm -rf $OFDIR/3j1t`)
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j1t/mu")
cp("$BASE/results/output/hists/bdt__3j1t_hmet.csv.mu", "$OFDIR/3j1t/mu/bdt.csv")
fr1 = run_fit("fits/3j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j1t/ele")
cp("$BASE/results/output/hists/bdt__3j1t_hmet.csv.ele", "$OFDIR/3j1t/ele/bdt.csv")
fr2 = run_fit("fits/3j1t/ele");
results[:r1__3j1t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/3j1t/mu/bdt_3j1t_hmet.csv.mu
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/3j1t/mu/results.json
# model files: fits/3j1t/ele/bdt_3j1t_hmet.csv.ele
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/3j1t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J1T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__3j1t.pdf")
savefig("$OFDIR/fit_corr__3j1t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11122cfd0>)

# %%
run(`rm -rf $OFDIR/3j2t`)
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j2t/mu")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.mu", "$OFDIR/3j2t/mu/bdt.csv")
fr1 = run_fit("fits/3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/3j2t/ele")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.ele", "$OFDIR/3j2t/ele/bdt.csv")
fr2 = run_fit("fits/3j2t/ele");
results[:r1__3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/3j2t/mu/bdt_3j2t_hmet.csv.mu
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/3j2t/mu/results.json
# model files: fits/3j2t/ele/bdt_3j2t_hmet.csv.ele
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/3j2t/ele/results.json

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__3j2t.pdf")
savefig("$OFDIR/fit_corr__3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10f4b0510>)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf $OFDIR/2j1t_3j2t`)
mkpath("$OFDIR/2j1t_3j2t/mu")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.mu", "$OFDIR/2j1t_3j2t/mu/bdt_3j2t.csv")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t_3j2t/mu/bdt_2j1t.csv")
fr1 = run_fit("fits/2j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t_3j2t/ele")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.ele", "$OFDIR/2j1t_3j2t/ele/bdt_3j2t.csv")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t_3j2t/ele/bdt_2j1t.csv")
fr2 = run_fit("fits/2j1t_3j2t/ele");
results[:r2__2j1t_3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/2j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu,fits/2j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# fits/2j1t_3j2t/mu/results.json
# model files: fits/2j1t_3j2t/ele/bdt_2j1t_hmet.csv.ele,fits/2j1t_3j2t/ele/bdt_3j2t_hmet.csv.ele
# ...

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t_3j2t.pdf")
savefig("$OFDIR/fit_corr__2j1t_3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10f4bbf10>)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf $OFDIR/2j1t_3j1t_3j2t`)
mkpath("$OFDIR/2j1t_3j1t_3j2t/mu")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j2t.csv")
cp("$BASE/results/output/hists/bdt__3j1t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j1t.csv")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.mu", "$OFDIR/2j1t_3j1t_3j2t/mu/bdt_2j1t.csv")
fr1 = run_fit("fits/2j1t_3j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("$OFDIR/2j1t_3j1t_3j2t/ele")
cp("$BASE/results/output/hists/bdt__3j2t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_3j2t.csv")
cp("$BASE/results/output/hists/bdt__3j1t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_3j1t.csv")
cp("$BASE/results/output/hists/bdt__2j1t_hmet.csv.ele", "$OFDIR/2j1t_3j1t_3j2t//ele/bdt_2j1t.csv")
fr2 = run_fit("fits/2j1t_3j1t_3j2t/ele");
results[:r3__2j1t_3j1t_3j2t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/2j1t_3j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu,fits/2j1t_3j1t_3j2t/mu/bdt_3j1t_hmet.csv.mu,fits/2j1t_3j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /Library/Python/2.7/site-packages/pytz/__init__.py:29: UserWarning: Module numpy was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/numpy/__init__.pyc, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# ...

# %%
a11, a12 = biaxes(0.07)
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J1T, 3J2T", y=0.86, size="large")
savefig("$OFDIR/fit_corr__2j1t_3j1t_3j2t.pdf")
savefig("$OFDIR/fit_corr__2j1t_3j1t_3j2t.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11c6e0110>)

# %%
totd = DataFrame()
for (k, v) in results
  for (lep, fr) in v
    d = to_df(fr)
    d["region"] = split(string(k), "__")[2]
    d["lepton"] = string(lep)
    totd = vcat(totd, d)
  end
end
writetable("$BASE/src/fraction_fit/$FITDIR/fits.mu.csv", totd[totd["lepton"] .== "mu", :])
writetable("$BASE/src/fraction_fit/$FITDIR/fits.ele.csv", totd[totd["lepton"] .== "ele", :])
# Out:
# to_df not defined
# while loading In[8], in expression starting on line 2
#  in anonymous at no file:4

# %%
prk = ["W+Jets, \$ \\gamma \$-jets,\nZ+jets, diboson", "\$ t \\bar{t} \$, tW, s, QCD", "Data", "t-channel"];

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_2j1t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_2j1t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](vars[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")
a2[:set_xlabel](vars[:bdt_sig_bg])

leg = a2[:legend](r, prk, fancybox=true,loc="best")
leg[:get_frame]()[:set_alpha](0.5)

a1[:grid]()
a2[:grid]()
suptitle("2J1T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__2j1t.pdf")
savefig("$OFDIR/fit_shape__2j1t.png")
# Out:
# bins__wzjets
# errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x11609c250>)

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j1t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_3j1t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](vars[:bdt_sig_bg])
a2[:set_xlabel](vars[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")

leg = a2[:legend](r, prk, fancybox=true)
leg[:get_frame]()[:set_alpha](0.5)

a2[:set_ylim](0, 0.12)
a1[:grid]()
a2[:grid]()
suptitle("3J1T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__3j1t.pdf")
savefig("$OFDIR/fit_shape__3j1t.png")
# Out:
# bins__wzjets
# errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x115216250>)

# %%
fig = figure(figsize=(9,4))
hists = {
  :mu=>read_hists("$OFDIR/2j1t_3j1t_3j2t/mu/bdt_3j2t.csv"),
  :ele=>read_hists("$OFDIR/2j1t_3j1t_3j2t/ele/bdt_3j2t.csv")
}
a1, a2 = biaxes(0.05)
kk = collect(keys(hists[:mu]))
r = eplot(a1, [normed(hists[:mu][k]) for k in kk]; drawstyle="steps-mid")
r = eplot(a2, [normed(hists[:ele][k]) for k in kk]; drawstyle="steps-mid")
a1[:set_xlabel](vars[:bdt_sig_bg])
a2[:set_xlabel](vars[:bdt_sig_bg])
a1[:set_title]("\$ \\mu \$")
a2[:set_title]("\$ e \$")
leg = a2[:legend](r, prk, fancybox=true)
leg[:get_frame]()[:set_alpha](0.5)
a1[:grid]()
a2[:grid]()
suptitle("3J2T", y=1.1, size="large")
savefig("$OFDIR/fit_shape__3j2t.pdf")
savefig("$OFDIR/fit_shape__3j2t.png")
# Out:
# bins__wzjets
# errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan errs__tchan edges__tchan
# bins__wzjets errs__wzjets edges__wzjets
# bins__ttjets errs__ttjets edges__ttjets
# bins__DATA errs__DATA edges__DATA
# bins__tchan
#  errs__tchan edges__tchan
# Figure(PyObject <matplotlib.figure.Figure object at 0x114918210>)

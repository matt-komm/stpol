# %%
include("../src/fraction_fit/hists.jl")
# Out:
# ...
# reweight_qcd (generic function with 1 method)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf ../src/fraction_fit/fits/`)

# %%
results = Dict();

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t/mu")
cp("../results/output/hists/bdt__2j1t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t/mu/bdt_2j1t_hmet.csv.mu")
fr1 = run_fit("fits/2j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t/ele")
cp("../results/output/hists/bdt__2j1t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t/ele/bdt_2j1t_hmet.csv.ele")
fr2 = run_fit("fits/2j1t/ele");

results[:singleregion_2j1t] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/2j1t/mu/bdt_2j1t_hmet.csv.mu
# fits/2j1t/mu/results.json
# model files: fits/2j1t/ele/bdt_2j1t_hmet.csv.ele
# fits/2j1t/ele/results.json

# %%
a11 = PyPlot.plt.axes((0.0, 0.0, 0.4, 1.0));
a12 = PyPlot.plt.axes((0.6, 0.0, 0.4, 1.0));
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x119082050>)
# PyObject <matplotlib.text.Text object at 0x11a215c10>

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/3j1t/mu")
cp("../results/output/hists/bdt__3j1t_hmet.csv.mu", "../src/fraction_fit/fits/3j1t/mu/bdt_3j1t_hmet.csv.mu")
fr1 = run_fit("fits/3j1t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/3j1t/ele")
cp("../results/output/hists/bdt__3j1t_hmet.csv.ele", "../src/fraction_fit/fits/3j1t/ele/bdt_3j1t_hmet.csv.ele")
fr2 = run_fit("fits/3j1t/ele");
# Out:
# model files: fits/3j1t/mu/bdt_3j1t_hmet.csv.mu
# fits/3j1t/mu/results.json
# model files: fits/3j1t/ele/bdt_3j1t_hmet.csv.ele
# fits/3j1t/ele/results.json

# %%
a11 = PyPlot.plt.axes((0.0, 0.0, 0.4, 1.0));
a12 = PyPlot.plt.axes((0.6, 0.0, 0.4, 1.0));
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J1T")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a22d190>)
# PyObject <matplotlib.text.Text object at 0x11a70ee10>

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/3j2t/mu")
cp("../results/output/hists/bdt__3j2t_hmet.csv.mu", "../src/fraction_fit/fits/3j2t/mu/bdt_3j2t_hmet.csv.mu")
fr1 = run_fit("fits/3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/3j2t/ele")
cp("../results/output/hists/bdt__3j2t_hmet.csv.ele", "../src/fraction_fit/fits/3j2t/ele/bdt_3j2t_hmet.csv.ele")
fr2 = run_fit("fits/3j2t/ele");
# Out:
# model files: fits/3j2t/mu/bdt_3j2t_hmet.csv.mu
# fits/3j2t/mu/results.json
# model files: fits/3j2t/ele/bdt_3j2t_hmet.csv.ele
# fits/3j2t/ele/results.json

# %%
a11 = PyPlot.plt.axes((0.0, 0.0, 0.4, 1.0));
a12 = PyPlot.plt.axes((0.6, 0.0, 0.4, 1.0));
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("3J2T")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a45d810>)
# PyObject <matplotlib.text.Text object at 0x11ad3d790>

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t_3j2t/mu")
cp("../results/output/hists/bdt__3j2t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu")
cp("../results/output/hists/bdt__2j1t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu")
fr1 = run_fit("fits/2j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t_3j2t/ele")
cp("../results/output/hists/bdt__3j2t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t_3j2t/ele/bdt_3j2t_hmet.csv.ele")
cp("../results/output/hists/bdt__2j1t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t_3j2t/ele/bdt_2j1t_hmet.csv.ele")
fr2 = run_fit("fits/2j1t_3j2t/ele");
results[:biregion] = {:mu=>fr1, :ele=>fr2};
# Out:
# model files: fits/2j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu,fits/2j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu
# fits/2j1t_3j2t/mu/results.json
# model files: fits/2j1t_3j2t/ele/bdt_2j1t_hmet.csv.ele,fits/2j1t_3j2t/ele/bdt_3j2t_hmet.csv.ele
# fits/2j1t_3j2t/ele/results.json

# %%
a11 = PyPlot.plt.axes((0.0, 0.0, 0.4, 1.0));
a12 = PyPlot.plt.axes((0.6, 0.0, 0.4, 1.0));
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J2T")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11aa86590>)
# PyObject <matplotlib.text.Text object at 0x11b0ec190>

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t_3j1t_3j2t/mu")
cp("../results/output/hists/bdt__3j2t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu")
cp("../results/output/hists/bdt__3j1t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/mu/bdt_3j1t_hmet.csv.mu")
cp("../results/output/hists/bdt__2j1t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu")
fr1 = run_fit("fits/2j1t_3j1t_3j2t/mu");
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t_3j1t_3j2t/ele")
cp("../results/output/hists/bdt__3j2t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/ele/bdt_3j2t_hmet.csv.ele")
cp("../results/output/hists/bdt__3j1t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/ele/bdt_3j1t_hmet.csv.ele")
cp("../results/output/hists/bdt__2j1t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t_3j1t_3j2t/ele/bdt_2j1t_hmet.csv.ele")
fr2 = run_fit("fits/2j1t_3j1t_3j2t/ele");
# Out:
# model files: fits/2j1t_3j1t_3j2t/mu/bdt_2j1t_hmet.csv.mu,fits/2j1t_3j1t_3j2t/mu/bdt_3j1t_hmet.csv.mu,fits/2j1t_3j1t_3j2t/mu/bdt_3j2t_hmet.csv.mu
# fits/2j1t_3j1t_3j2t/mu/results.json
# model files: fits/2j1t_3j1t_3j2t/ele/bdt_2j1t_hmet.csv.ele,fits/2j1t_3j1t_3j2t/ele/bdt_3j1t_hmet.csv.ele,fits/2j1t_3j1t_3j2t/ele/bdt_3j2t_hmet.csv.ele
# fits/2j1t_3j1t_3j2t/ele/results.json

# %%
fig = figure()
a11 = PyPlot.plt.axes((0.0, 0.0, 0.4, 1.0));
a12 = PyPlot.plt.axes((0.6, 0.0, 0.4, 1.0));
show_corr(a11, fr1; subtitle="\$ \\mu \$");
show_corr(a12, fr2; subtitle="\$ e \$");
suptitle("2J1T, 3J1T, 3J2T")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a2acf90>)
# PyObject <matplotlib.text.Text object at 0x11b450c10>

# %%
include("../src/fraction_fit/hists.jl")
# Out:
# ...
# yields (generic function with 2 methods)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
run(`rm -rf ../src/fraction_fit/fits/`)

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t/mu")
cp("../results/output/hists/bdt__2j1t_hmet.csv.mu", "../src/fraction_fit/fits/2j1t/mu/bdt_2j1t_hmet.csv.mu")
fr1 = run_fit("fits/2j1t/mu");
# Out:
# model files: fits/2j1t/mu/bdt_2j1t_hmet.csv.mu

# %%
cd("/Users/joosep/Documents/stpol/notebooks")
mkpath("../src/fraction_fit/fits/2j1t/ele")
cp("../results/output/hists/bdt__2j1t_hmet.csv.ele", "../src/fraction_fit/fits/2j1t/ele/bdt_2j1t_hmet.csv.ele")
fr2 = run_fit("fits/2j1t/ele");
# Out:
# model files: fits/2j1t/ele/bdt_2j1t_hmet.csv.ele

# %%
a = axes();
show_corr(a, fr1)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117e7fed0>)
# PyObject <matplotlib.image.AxesImage object at 0x117ef5fd0>

# %%
a = axes();
show_corr(a, fr2)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1145bea10>)
# PyObject <matplotlib.image.AxesImage object at 0x1182cf910>

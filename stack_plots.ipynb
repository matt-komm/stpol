# %%
# %time %run plots/load_histos2.py
fi = File(fnames[0]).Get(subpath)
# Out:
# CPU times: user 1.2 s, sys: 108 ms, total: 1.31 s
# Wall time: 1.4 s

# %%
pat = "iso/(.*)/.*/(.*)/channel/ele/ele__iso/jet/2j/tag/1t/met/met__met/signalenr/(.*)/(.*)/(.*)/cos_theta"
# %time ret = load_file(fi, pat)
# Out:
# CPU times: user 19.7 s, sys: 1.27 s, total: 21 s
# Wall time: 20.8 s

# %%
for a, b in ret:
    print a, b
# Out:
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__wjets_mg_flavour_shape_weight_up__ele', 'cos_theta') Hist('cos_theta')
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__b_weight_nominal_BCup__ele', 'cos_theta') Hist('cos_theta')
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__electron_TriggerWeight_up__ele', 'cos_theta') Hist('cos_theta')
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__b_weight_nominal_BCdown__ele', 'cos_theta') Hist('cos_theta')
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__b_weight_nominal_Ldown__ele', 'cos_theta') Hist('cos_theta')
# ('UnclusteredEnDown', 'ZZ.root', 'cutbased/mtop/mtop__SR/etalj', 'etalj__g2_5', 'weight__electron_TriggerWeight_down__ele', 'cos_theta') Hist('cos_theta')
# ...

# %%
subpath + pat
# Out:
# 'hdfs/local/stpol/step3/Aug4_0eb863_full/ele/mc/iso/nominal/Jul15/.*/.*/cos_theta.*'

# %%
fi.GetName()
# Out:
# 'nominal'

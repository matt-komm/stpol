# %% [markdown]
# ## Setup

# %%
from plots.common.hist_plots import ipy_show_canv
from plots.syst_band import PlotDef, data_mc_plot
from plots.common.cross_sections import lumis
from plots.common.tdrstyle import tdrstyle
tdrstyle()
# Out:
# 1

# %% [markdown]
# ## Scale factors

# %%
from plots.fit_scale_factors import fitpars_process
from plots.qcd_scale_factors import load_qcd_sf
qcd_sfs = dict()
qcd_sfs['mu'] = load_qcd_sf('mu', 50)
qcd_sfs['ele'] = load_qcd_sf('ele', 45)
fitpars_process['final_2j1t_mva']['mu'], fitpars_process['final_2j1t_mva']['ele'], qcd_sfs
# Out:
# ([(['tchan'], 1.031894, 0.060219),
#   (['ttjets', 'twchan', 'schan', 'qcd'], 0.91475, 0.106069),
#   (['wjets', 'diboson', 'dyjets'], 1.604641, 0.234251)],
#  [(['tchan'], 0.956595, 0.092058),
#   (['ttjets', 'twchan', 'schan', 'qcd'], 0.982722, 0.176448),
#   (['wjets', 'diboson', 'dyjets'], 1.382914, 0.570805)],
#  {'ele': 3.679799, 'mu': 3.279511})

# %%
sfs = dict()

#Fit coefficients need fixing, esp. for muons
sfs['mu'] = [
    (['tchan'], 1.031894, -1),
    (['ttjets', 'twchan', 'schan'], 0.91475, -1),
    (['qcd'], qcd_sfs['mu']*0.91475, -1),
    (['wjets', 'diboson', 'dyjets'], 1.604641, -1)
]
sfs['ele'] = [
    (['tchan'], 0.956595, -1),
    (['ttjets', 'twchan', 'schan', 'qcd'], 0.982722, -1),
    (['qcd'], qcd_sfs['ele']*0.982722, -1),
    (['wjets', 'diboson', 'dyjets'], 1.382914, -1)
]
sfs
# Out:
# {'ele': [(['tchan'], 0.74, -1),
#   (['ttjets', 'twchan', 'schan', 'qcd'], 0.982722, -1),
#   (['qcd'], 3.616219432878, -1),
#   (['wjets', 'diboson', 'dyjets'], 1.382914, -1)],
#  'mu': [(['tchan'], 1.031894, -1),
#   (['ttjets', 'twchan', 'schan'], 0.91475, -1),
#   (['qcd'], 2.99993268725, -1),
#   (['wjets', 'diboson', 'dyjets'], 1.604641, -1)]}

# %%
import copy
#Fix muon QCD SF by hand
sf = copy.deepcopy(sfs['mu'])
sf[2] = (sf[2][0], 0.5*sf[2][1], -1)
sf
# Out:
# [(['tchan'], 1.031894, -1),
#  (['ttjets', 'twchan', 'schan'], 0.91475, -1),
#  (['qcd'], 1.499966343625, -1),
#  (['wjets', 'diboson', 'dyjets'], 1.604641, -1)]

# %% [markdown]
# ## Plots

# %%
def pd(var, cut, channel, **kwargs):
    channels_pretty = {"mu":"Muon", "ele":"Electrons"}
    return PlotDef(
        infile="out/hists/hists_merged__mva_loose__%s_%s.root" % (var, channel),
        lumi=lumis["Aug4_0eb863_full"]["iso"][channel],
        var=var,
        channel_pretty=channels_pretty[channel],
        systematics='.*',
        systematics_shapeonly=True,
        lb_comments=', all syst.',
        save_name="out/plots/%s_%s_%s.pdf" % (cut, var, channel),
        process_scale_factor = sfs[channel],
        **kwargs
    )

def save_and_show(c):
    c.SaveAs(h.save_name)
    r = ipy_show_canv(c)
    c.Close() #Need to close to prevent ROOT crash
    return r

h = pd("abs_eta_lj", "2j1t_mva_loose", "mu", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'muon_isoweight', 'pu_weight', 'en', 'ttbar_scale', 'res', 'tchan_scale', 'b_weight_nominal_bc', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'muon_triggerweight', 'muon_idweight', 'wjets_mg_flavour_shape_weight', 'mass', 'top_pt', 'lepton_weight_shape', 'qcd_yield']
# INFO:plots.syst_band] Systematic en, 114.9913
# INFO:plots.syst_band] Systematic tchan_scale, 54.6643
# INFO:plots.syst_band] Systematic res, 44.3167
# INFO:plots.syst_band] Systematic qcd_iso, 32.4838
# INFO:plots.syst_band] Systematic pu_weight, 24.8119
# INFO:plots.syst_band] Systematic mass, 23.5586
# INFO:plots.syst_band] Systematic ttbar_scale, 16.4552
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_abs_eta_lj_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 11.9307551011 111.0
# schan 14.4493943751 72.0
# tchan 2176.40828347 26058.0
# TTJets 434.977909006 7788.0
# qcd 134.996969223 306.0
# tWchan 31.5713647306 99.0
# WJets 528.948039025 574.0
# DYJets 42.4865412712 14.0
# MC: 3375.77 Data: 3644.00

# %%
h = pd("abs_eta_lj", "2j1t_mva_loose", "ele", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'pu_weight', 'en', 'ttbar_scale', 'res', 'tchan_scale', 'electron_triggerweight', 'b_weight_nominal_bc', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'electron_idweight', 'wjets_mg_flavour_shape_weight', 'mass', 'top_pt', 'lepton_weight_shape', 'qcd_yield']
# INFO:plots.syst_band] Systematic tchan_scale, 54.2672
# INFO:plots.syst_band] Systematic en, 49.0016
# INFO:plots.syst_band] Systematic mass, 25.2672
# INFO:plots.syst_band] Systematic res, 24.8301
# INFO:plots.syst_band] Systematic ttbar_scale, 20.1228
# INFO:plots.syst_band] Systematic unclustereden, 10.5988
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 10.2518
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_abs_eta_lj_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 6.09187864512 82.0
# qcd 39.3088793755 357.0
# TTJets 257.71445936 4921.0
# tchan 795.62778151 13606.0
# schan 7.12882661819 33.0
# tWchan 21.4136937857 72.0
# WJets 208.217227146 259.0
# DYJets 27.2467367649 10.0
# MC: 1362.75 Data: 1587.00

# %%
h = pd("top_mass_sr", "2j1t_mva_loose", "mu", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['ttbar_scale', 'wjets_mg_flavour_flat_weight', 'unclustereden', 'muon_isoweight', 'b_weight_nominal_l', 'pu_weight', 'en', 'tchan_scale', 'lepton_weight_shape', 'qcd_iso', 'top_pt', 'muon_triggerweight', 'wjets_mg_flavour_shape_weight', 'res', 'b_weight_nominal_bc', 'muon_idweight', 'qcd_yield', 'mass']
# INFO:plots.syst_band] Systematic mass, 151.7868
# INFO:plots.syst_band] Systematic qcd_iso, 109.1376
# INFO:plots.syst_band] Systematic tchan_scale, 67.8464
# INFO:plots.syst_band] Systematic en, 37.1110
# INFO:plots.syst_band] Systematic res, 33.5259
# INFO:plots.syst_band] Systematic ttbar_scale, 20.8382
# INFO:plots.syst_band] Systematic unclustereden, 16.9105
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_top_mass_sr_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# schan 16.8153504431 72.0
# DYJets 39.7238578796 14.0
# TTJets 528.112654686 7788.0
# WJets 513.211801529 574.0
# tWchan 39.0212897062 99.0
# diboson 12.1600257158 111.0
# qcd 677.984783173 306.0
# tchan 2418.21726227 26058.0
# MC: 4245.25 Data: 4004.00

# %%
h = pd("top_mass_sr", "2j1t_mva_loose", "ele", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['ttbar_scale', 'wjets_mg_flavour_flat_weight', 'wjets_mg_flavour_shape_weight', 'unclustereden', 'b_weight_nominal_l', 'pu_weight', 'electron_idweight', 'en', 'lepton_weight_shape', 'electron_triggerweight', 'top_pt', 'res', 'b_weight_nominal_bc', 'tchan_scale', 'qcd_iso', 'qcd_yield', 'mass']
# INFO:plots.syst_band] Systematic mass, 104.6344
# INFO:plots.syst_band] Systematic tchan_scale, 55.9453
# INFO:plots.syst_band] Systematic en, 28.4157
# INFO:plots.syst_band] Systematic res, 22.7422
# INFO:plots.syst_band] Systematic qcd_iso, 19.6314
# INFO:plots.syst_band] Systematic ttbar_scale, 17.1618
# INFO:plots.syst_band] Systematic unclustereden, 7.7412
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_top_mass_sr_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# schan 7.49905471283 33.0
# TTJets 310.295071602 4921.0
# WJets 208.062105179 259.0
# DYJets 27.2467366457 10.0
# diboson 6.45646841824 82.0
# tWchan 27.9710653722 72.0
# qcd 184.751734257 357.0
# tchan 1165.3871994 13606.0
# MC: 1937.67 Data: 1796.00

# %%
h = pd("cos_theta", "2j1t_mva_loose", "mu", rebin=6)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'b_weight_nominal_l', 'qcd_yield', 'muon_idweight', 'pu_weight', 'wjets_mg_flavour_shape_weight', 'tchan_scale', 'b_weight_nominal_bc', 'muon_isoweight', 'muon_triggerweight', 'ttbar_scale', 'en', 'lepton_weight_shape', 'mass', 'top_pt', 'unclustereden', 'res']
# INFO:plots.syst_band] Systematic qcd_iso, 109.1175
# INFO:plots.syst_band] Systematic tchan_scale, 56.1442
# INFO:plots.syst_band] Systematic mass, 36.0970
# INFO:plots.syst_band] Systematic ttbar_scale, 24.2148
# INFO:plots.syst_band] Systematic en, 23.6678
# INFO:plots.syst_band] Systematic res, 21.6920
# INFO:plots.syst_band] Systematic unclustereden, 11.2726
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_cos_theta_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 13.3271232247 111.0
# qcd 917.97939682 306.0
# DYJets 42.5331523195 14.0
# tchan 2517.53311157 26058.0
# WJets 609.549732208 574.0
# schan 17.4481881559 72.0
# tWchan 39.9546144009 99.0
# TTJets 555.984514236 7788.0
# MC: 4714.31 Data: 4275.00

# %%
h = pd("cos_theta", "2j1t_mva_loose", "ele", rebin=6)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'b_weight_nominal_l', 'pu_weight', 'wjets_mg_flavour_shape_weight', 'electron_triggerweight', 'electron_idweight', 'tchan_scale', 'b_weight_nominal_bc', 'ttbar_scale', 'en', 'lepton_weight_shape', 'mass', 'qcd_yield', 'top_pt', 'res', 'unclustereden']
# INFO:plots.syst_band] Systematic tchan_scale, 47.1255
# INFO:plots.syst_band] Systematic mass, 23.8421
# INFO:plots.syst_band] Systematic qcd_iso, 23.6723
# INFO:plots.syst_band] Systematic res, 20.4938
# INFO:plots.syst_band] Systematic en, 18.1069
# INFO:plots.syst_band] Systematic ttbar_scale, 16.4143
# INFO:plots.syst_band] Systematic unclustereden, 11.3495
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_cos_theta_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 7.38015799969 82.0
# qcd 350.831754684 357.0
# DYJets 31.1624500751 10.0
# tchan 952.381902695 13606.0
# WJets 261.890781403 259.0
# schan 8.36906430125 33.0
# tWchan 31.3366082907 72.0
# TTJets 344.581638336 4921.0
# MC: 1987.93 Data: 1962.00

# %%
h = pd("mtw_50_150", "2j1t_mva_loose", "mu", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['b_weight_nominal_bc', 'top_pt', 'res', 'unclustereden', 'wjets_mg_flavour_flat_weight', 'muon_isoweight', 'en', 'qcd_yield', 'lepton_weight_shape', 'wjets_mg_flavour_shape_weight', 'pu_weight', 'mass', 'tchan_scale', 'ttbar_scale', 'qcd_iso', 'b_weight_nominal_l', 'muon_idweight', 'muon_triggerweight']
# INFO:plots.syst_band] Systematic qcd_iso, 66.9462
# INFO:plots.syst_band] Systematic mass, 51.3888
# INFO:plots.syst_band] Systematic tchan_scale, 44.9029
# INFO:plots.syst_band] Systematic res, 34.5051
# INFO:plots.syst_band] Systematic en, 30.1594
# INFO:plots.syst_band] Systematic ttbar_scale, 25.6136
# INFO:plots.syst_band] Systematic unclustereden, 19.6951
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_mtw_50_150_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# qcd 911.979519844 306.0
# TTJets 555.846230209 7788.0
# tchan 2517.53306139 26058.0
# WJets 609.549738765 574.0
# tWchan 39.9546158016 99.0
# DYJets 42.5331523418 14.0
# diboson 13.3271237016 111.0
# schan 17.4481887221 72.0
# MC: 4708.17 Data: 4274.00

# %%
h = pd("mtw_50_150", "2j1t_mva_loose", "ele", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['top_pt', 'res', 'unclustereden', 'electron_idweight', 'b_weight_nominal_bc', 'qcd_yield', 'electron_triggerweight', 'wjets_mg_flavour_shape_weight', 'pu_weight', 'mass', 'tchan_scale', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'lepton_weight_shape', 'en', 'ttbar_scale', 'b_weight_nominal_l']
# INFO:plots.syst_band] Systematic tchan_scale, 52.5085
# INFO:plots.syst_band] Systematic res, 24.3569
# INFO:plots.syst_band] Systematic mass, 23.2856
# INFO:plots.syst_band] Systematic qcd_iso, 18.1583
# INFO:plots.syst_band] Systematic en, 16.9171
# INFO:plots.syst_band] Systematic unclustereden, 15.2511
# INFO:plots.syst_band] Systematic ttbar_scale, 14.1384
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_mtw_50_150_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# TTJets 274.81587401 4921.0
# tchan 798.658645168 13606.0
# WJets 221.769536972 259.0
# tWchan 22.7651356459 72.0
# qcd 159.20096314 357.0
# DYJets 18.1278424263 10.0
# diboson 5.84131621197 82.0
# schan 7.47775089741 33.0
# MC: 1508.66 Data: 1633.00

# %%
from plots.common.hist_plots import ipy_show_canv
from plots.syst_band import PlotDef, data_mc_plot
from plots.common.cross_sections import lumis
from plots.common.tdrstyle import tdrstyle
tdrstyle()
# Out:
# 1

# %%
h = PlotDef(
    infile="out/hists/hists_merged__abs_eta_lj_mu.root",
    lumi=lumis["Aug4_0eb863_full"]["iso"]["mu"],
    var="abs_eta_lj",
    channel_pretty="Muon",
    legend_pos='top-right',
    #legend_nudge_y=-0.12,
    
    systematics='.*',
    log=False,
    systematics_shapeonly=False,
    save_name='2j1t_mva__abs_eta_lj__all_syst_mu.png',
    lb_comments=', all syst.',
    lumi_pos='top-left',

    rebin=3
)
c = data_mc_plot(h)
r = ipy_show_canv(c)
c.Close()
r
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'muon_isoweight', 'pu_weight', 'en', 'ttbar_scale', 'qcd_yield', 'res', 'b_weight_nominal_bc', 'muon_triggerweight', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'tchan_scale', 'mass', 'muon_idweight', 'wjets_mg_flavour_shape_weight', 'top_pt']
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 141.6822
# INFO:plots.syst_band] Systematic en, 93.6462
# INFO:plots.syst_band] Systematic tchan_scale, 91.5565
# INFO:plots.syst_band] Systematic mass, 45.8629
# INFO:plots.syst_band] Systematic res, 32.9170
# INFO:plots.syst_band] Systematic b_weight_nominal_bc, 29.2867
# INFO:plots.syst_band] Systematic ttbar_scale, 24.1904
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# TTJets 434.977905195 7788.0
# diboson 7.43515555933 111.0
# tchan 2109.13939667 26058.0
# qcd 45.0 306.0
# ...

# %%
h = PlotDef(
    infile="out/hists/hists_merged__abs_eta_lj_ele.root",
    lumi=lumis["Aug4_0eb863_full"]["iso"]["ele"],
    var="abs_eta_lj",
    channel_pretty="Electron",
    legend_pos='top-right',
    #legend_nudge_y=-0.12,
    
    systematics='.*',
    log=False,
    systematics_shapeonly=:q
    "q:q
    :q
1    ,
    save_name='2j1t_mva__abs_eta_lj__all_syst_ele.png',
    lb_comments=', all syst.',
    lumi_pos='top-left',

    rebin=3
)
c = data_mc_plot(h)
r = ipy_show_canv(c)
c.Close()
r
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'pu_weight', 'en', 'ttbar_scale', 'qcd_yield', 'tchan_scale', 'electron_triggerweight', 'b_weight_nominal_bc', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'electron_idweight', 'res', 'wjets_mg_flavour_shape_weight', 'top_pt', 'mass']
# INFO:plots.syst_band] Systematic tchan_scale, 63.2853
# INFO:plots.syst_band] Systematic en, 51.8151
# INFO:plots.syst_band] Systematic res, 27.1319
# INFO:plots.syst_band] Systematic mass, 25.4683
# INFO:plots.syst_band] Systematic ttbar_scale, 19.0845
# INFO:plots.syst_band] Systematic unclustereden, 8.7900
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 8.2651
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 4.40510318801 82.0
# qcd 40.0 357.0
# TTJets 257.714458257 4921.0
# tWchan 21.4136929535 72.0
# tchan 1075.17268878 13606.0
# ...

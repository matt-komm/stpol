# %% [markdown]
# ## Setup

# %%
from plots.common.hist_plots import ipy_show_canv
from plots.syst_band import PlotDef, data_mc_plot, logger
logger.setLevel("INFO")
from plots.common.cross_sections import lumis
from plots.common.tdrstyle import tdrstyle
tdrstyle()
# Out:
# 1

# %% [markdown]
# ## Scale factors

# %%
from plots.fit_scale_factors import fitpars_process
from plots.qcd_scale_factors import load_qcd_sf

#Determined from the QCD fit
qcd_mt_fit_sfs = dict()
qcd_mt_fit_sfs['mu'] = load_qcd_sf('mu', 50)
qcd_mt_fit_sfs['ele'] = load_qcd_sf('ele', 45)

#Determined as the ratio of the integral of anti-iso data after full selection / full selection minus MVA
#See qcd_scale_factors.ipynb for determination
qcd_loose_to_MVA_sfs = {
    'mu': 0.114379084967,
    'ele': 0.0728291316527,
}
fit_sfs = dict()

fit_sfs['mu'] = [x[1] for x in fitpars_process['final_2j1t_mva']['mu']]
fit_sfs['ele'] = [x[1] for x in fitpars_process['final_2j1t_mva']['ele']]

# %%
sfs = dict()

def scale_factors(channel, apply_MVA=True, mt_cut=False):
    tchan = fit_sfs[channel][0]
    top = fit_sfs[channel][1]
    wzjets = fit_sfs[channel][2]
    qcd = top
    if apply_MVA:
        qcd = qcd * qcd_loose_to_MVA_sfs[channel]
    if mt_cut is False:
        qcd = qcd * qcd_mt_fit_sfs[channel]
    else:
        qcd = qcd * load_qcd_sf(channel, mt_cut)
                             
    ret = [
        (['tchan'], tchan, -1),
        (['TTJets', 'tWchan', 'schan'], top, -1),
        (['qcd'], qcd, -1),
        (['WJets', 'diboson', 'DYJets'], wzjets, -1)
    ]
    return ret
scale_factors('mu', False, 0), scale_factors('ele', False, 0)
# Out:
# ([(['tchan'], 0.987681, -1),
#   (['TTJets', 'tWchan', 'schan'], 0.820195, -1),
#   (['qcd'], 5.002967227155, -1),
#   (['WJets', 'diboson', 'DYJets'], 1.923652, -1)],
#  [(['tchan'], 0.856671, -1),
#   (['TTJets', 'tWchan', 'schan'], 0.824649, -1),
#   (['qcd'], 3.7437819380010002, -1),
#   (['WJets', 'diboson', 'DYJets'], 2.18184, -1)])

# %%
cutname = "2j1t_mva_loose"
hists_dir = "hists/Aug26"

# %% [markdown]
# ## Plots

# %%
def pd(var, cut, channel, **kwargs):
    channels_pretty = {"mu":"Muon", "ele":"Electrons"}
    return PlotDef(
        infile=hists_dir+"/hists_merged__%s__%s_%s.root" % (cut, var, channel),
        lumi=lumis["343e0a9_Aug22"]["iso"][channel],
        var=var,
        channel_pretty=channels_pretty[channel],
        systematics='.*',
        systematics_shapeonly=True,
        lb_comments=', all syst.',
        save_name="out/plots/%s_%s_%s.pdf" % (cut, var, channel),
        process_scale_factor = scale_factors(channel),
        **kwargs
    )

def save_and_show(c):
    c.SaveAs(h.save_name)
    r = ipy_show_canv(c)
    c.Close() #Need to close to prevent ROOT crash
    return r

h = pd("abs_eta_lj", cutname, "mu", rebin=2, legend_pos='top-left', legend_nudge_x=-0.05, log=False)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'b_weight_nominal_bc', 'pu_weight', 'muon_isoweight', 'en', 'ttbar_scale', 'qcd_yield', 'tchan_scale', 'res', 'wjets_mg_flavour_shape_weight', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'muon_triggerweight', 'muon_idweight', 'mass', 'top_pt', 'lepton_weight_shape']
# INFO:plots.syst_band] Systematic en, 106.5494
# INFO:plots.syst_band] Systematic tchan_scale, 76.9477
# INFO:plots.syst_band] Systematic res, 38.8930
# INFO:plots.syst_band] Systematic mass, 36.1418
# INFO:plots.syst_band] Systematic pu_weight, 27.5265
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 22.6722
# INFO:plots.syst_band] Systematic unclustereden, 17.2938
# WARNING:ROOT.TCanvas.Constructor] Deleting canvas with same name: c
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_abs_eta_lj_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 16.1504218727 114.0
# tchan 2342.06591818 25987.0
# qcd 95.6087483168 305.0
# TTJets 446.812215461 7798.0
# schan 15.8155734725 75.0
# tWchan 30.4875086844 94.0
# WJets 1155.40578645 573.0
# DYJets 68.3786268532 13.0
# MC: 4170.72 Data: 4303.00

# %%
h = pd("abs_eta_lj", cutname, "ele", rebin=2, legend_pos='top-left', legend_nudge_x=-0.05, log=False)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'b_weight_nominal_l', 'pu_weight', 'en', 'electron_triggerweight', 'res', 'tchan_scale', 'b_weight_nominal_bc', 'wjets_mg_flavour_flat_weight', 'qcd_iso', 'ttbar_scale', 'electron_idweight', 'wjets_mg_flavour_shape_weight', 'mass', 'top_pt', 'lepton_weight_shape', 'qcd_yield']
# INFO:plots.syst_band] Systematic tchan_scale, 56.1238
# INFO:plots.syst_band] Systematic en, 52.6497
# INFO:plots.syst_band] Systematic res, 42.3116
# INFO:plots.syst_band] Systematic mass, 23.8007
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 14.9287
# INFO:plots.syst_band] Systematic ttbar_scale, 12.9076
# INFO:plots.syst_band] Systematic pu_weight, 10.4643
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_abs_eta_lj_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 10.5999616235 82.0
# qcd 86.6415238082 381.0
# TTJets 258.963615961 4913.0
# tchan 1003.39269581 13592.0
# schan 6.20152906282 32.0
# tWchan 23.1374560554 71.0
# WJets 520.999383509 262.0
# DYJets 63.7525348663 9.0
# MC: 1973.69 Data: 1986.00

# %%
h = pd("top_mass_sr", cutname, "mu", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['ttbar_scale', 'wjets_mg_flavour_flat_weight', 'wjets_mg_flavour_shape_weight', 'unclustereden', 'b_weight_nominal_l', 'pu_weight', 'en', 'lepton_weight_shape', 'muon_triggerweight', 'b_weight_nominal_bc', 'muon_idweight', 'res', 'tchan_scale', 'top_pt', 'mass', 'qcd_yield', 'muon_isoweight', 'qcd_iso']
# INFO:plots.syst_band] Systematic mass, 137.1039
# INFO:plots.syst_band] Systematic tchan_scale, 71.2833
# INFO:plots.syst_band] Systematic en, 41.1806
# INFO:plots.syst_band] Systematic res, 38.0500
# INFO:plots.syst_band] Systematic unclustereden, 34.5295
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 23.4699
# INFO:plots.syst_band] Systematic ttbar_scale, 17.4460
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_top_mass_sr_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# schan 15.3202123642 75.0
# DYJets 68.3786270618 13.0
# TTJets 424.703115463 7798.0
# WJets 979.189136505 573.0
# diboson 14.7194227576 114.0
# tWchan 30.104362607 94.0
# qcd 71.4714574814 305.0
# tchan 2248.96447754 25987.0
# MC: 3852.85 Data: 4029.00

# %%
h = pd("top_mass_sr", cutname, "ele", rebin=6, legend_pos='top-right', legend_nudge_x=-0.05)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['ttbar_scale', 'wjets_mg_flavour_flat_weight', 'unclustereden', 'qcd_yield', 'b_weight_nominal_l', 'pu_weight', 'electron_idweight', 'en', 'lepton_weight_shape', 'electron_triggerweight', 'wjets_mg_flavour_shape_weight', 'top_pt', 'res', 'b_weight_nominal_bc', 'tchan_scale', 'qcd_iso', 'mass']
# INFO:plots.syst_band] Systematic mass, 87.4428
# INFO:plots.syst_band] Systematic tchan_scale, 51.8376
# INFO:plots.syst_band] Systematic res, 44.5794
# INFO:plots.syst_band] Systematic en, 37.8651
# INFO:plots.syst_band] Systematic unclustereden, 21.1148
# INFO:plots.syst_band] Systematic ttbar_scale, 14.9181
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 10.6731
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_top_mass_sr_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# schan 5.54113057256 32.0
# DYJets 63.7525317669 9.0
# TTJets 233.149522781 4913.0
# WJets 418.451489449 262.0
# diboson 9.53271627426 82.0
# tWchan 20.6013181806 71.0
# qcd 43.6618697643 381.0
# tchan 949.516899109 13592.0
# MC: 1744.21 Data: 1816.00

# %%
h = pd("cos_theta", cutname, "mu", rebin=4)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'b_weight_nominal_l', 'muon_idweight', 'pu_weight', 'wjets_mg_flavour_shape_weight', 'lepton_weight_shape', 'tchan_scale', 'b_weight_nominal_bc', 'muon_isoweight', 'muon_triggerweight', 'res', 'mass', 'qcd_yield', 'en', 'unclustereden', 'top_pt', 'ttbar_scale']
# INFO:plots.syst_band] Systematic tchan_scale, 71.3582
# INFO:plots.syst_band] Systematic res, 56.6643
# INFO:plots.syst_band] Systematic mass, 40.8062
# INFO:plots.syst_band] Systematic en, 35.0052
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 32.8662
# INFO:plots.syst_band] Systematic ttbar_scale, 21.5298
# INFO:plots.syst_band] Systematic unclustereden, 21.0147
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_cos_theta_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 16.1504215086 114.0
# qcd 95.6087503433 305.0
# DYJets 68.3786257803 13.0
# tchan 2342.06606865 25987.0
# WJets 1155.40578079 573.0
# schan 15.815573588 75.0
# tWchan 30.487508297 94.0
# TTJets 446.812162399 7798.0
# MC: 4170.72 Data: 4303.00

# %%
h = pd("cos_theta", cutname, "ele", rebin=4)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'b_weight_nominal_l', 'pu_weight', 'wjets_mg_flavour_shape_weight', 'electron_triggerweight', 'electron_idweight', 'tchan_scale', 'b_weight_nominal_bc', 'ttbar_scale', 'en', 'lepton_weight_shape', 'mass', 'qcd_yield', 'top_pt', 'unclustereden', 'res']
# INFO:plots.syst_band] Systematic tchan_scale, 64.0482
# INFO:plots.syst_band] Systematic res, 47.3082
# INFO:plots.syst_band] Systematic en, 47.1701
# INFO:plots.syst_band] Systematic unclustereden, 40.2121
# INFO:plots.syst_band] Systematic mass, 27.9827
# INFO:plots.syst_band] Systematic ttbar_scale, 16.2774
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 12.3875
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_cos_theta_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 10.5999613404 82.0
# qcd 86.6415228844 381.0
# DYJets 63.7525316942 9.0
# tchan 1003.39267159 13592.0
# WJets 520.999392509 262.0
# schan 6.2015293017 32.0
# tWchan 23.1374567151 71.0
# TTJets 258.963620186 4913.0
# MC: 1973.69 Data: 1986.00

# %%
h = pd("mtw_50_150", cutname, "mu", rebin=3, legend_pos='top-right', legend_nudge_x=-0.05)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['b_weight_nominal_bc', 'top_pt', 'res', 'unclustereden', 'wjets_mg_flavour_flat_weight', 'muon_isoweight', 'qcd_yield', 'lepton_weight_shape', 'wjets_mg_flavour_shape_weight', 'pu_weight', 'b_weight_nominal_l', 'mass', 'tchan_scale', 'ttbar_scale', 'qcd_iso', 'en', 'muon_idweight', 'muon_triggerweight']
# INFO:plots.syst_band] Systematic res, 61.8949
# INFO:plots.syst_band] Systematic tchan_scale, 54.5775
# INFO:plots.syst_band] Systematic mass, 43.8581
# INFO:plots.syst_band] Systematic en, 42.8230
# INFO:plots.syst_band] Systematic unclustereden, 36.3604
# INFO:plots.syst_band] Systematic ttbar_scale, 23.9055
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 17.5553
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_mtw_50_150_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# qcd 95.2952764034 305.0
# TTJets 446.660329525 7798.0
# tchan 2342.06593212 25987.0
# WJets 1155.40579551 573.0
# tWchan 30.487508744 94.0
# DYJets 68.3786254227 13.0
# diboson 16.1504215896 114.0
# schan 15.8155737817 75.0
# MC: 4170.26 Data: 4302.00

# %%
h = pd("mtw_50_150", cutname, "ele", rebin=3, legend_pos='top-right', legend_nudge_x=-0.05)
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['b_weight_nominal_bc', 'top_pt', 'res', 'unclustereden', 'electron_idweight', 'qcd_yield', 'electron_triggerweight', 'wjets_mg_flavour_shape_weight', 'pu_weight', 'mass', 'tchan_scale', 'wjets_mg_flavour_flat_weight', 'b_weight_nominal_l', 'qcd_iso', 'lepton_weight_shape', 'en', 'ttbar_scale']
# INFO:plots.syst_band] Systematic res, 51.9385
# INFO:plots.syst_band] Systematic tchan_scale, 46.8833
# INFO:plots.syst_band] Systematic en, 32.1113
# INFO:plots.syst_band] Systematic unclustereden, 30.3786
# INFO:plots.syst_band] Systematic mass, 21.1399
# INFO:plots.syst_band] Systematic ttbar_scale, 13.1652
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 11.2055
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_mva_loose_mtw_50_150_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# TTJets 206.938147206 4913.0
# tchan 839.969616342 13592.0
# WJets 439.071787387 262.0
# tWchan 16.7162298262 71.0
# qcd 39.7959754765 381.0
# DYJets 33.1865949631 9.0
# diboson 8.26711846329 82.0
# schan 5.63445261866 32.0
# MC: 1589.58 Data: 1653.00

# %%
h = pd("bdt_discr", "2j1t_baseline", "mu", rebin=3, legend_pos='top-right', legend_nudge_x=-0.05, log=True, max_bin_mult_log=1000)
h.process_scale_factor = scale_factors('mu', False)
#h.systematics_shapeonly = False
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['muon_idweight', 'unclustereden', 'wjets_mg_flavour_shape_weight', 'qcd_yield', 'tchan_scale', 'b_weight_nominal_bc', 'qcd_iso', 'b_weight_nominal_l', 'wjets_mg_flavour_flat_weight', 'muon_isoweight', 'top_pt', 'ttbar_scale', 'lepton_weight_shape', 'mass', 'muon_triggerweight', 'pu_weight', 'en', 'res']
# INFO:plots.syst_band] Systematic mass, 692.7245
# INFO:plots.syst_band] Systematic top_pt, 313.4987
# INFO:plots.syst_band] Systematic en, 289.3344
# INFO:plots.syst_band] Systematic res, 221.1043
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 204.6197
# INFO:plots.syst_band] Systematic tchan_scale, 199.0952
# INFO:plots.syst_band] Systematic unclustereden, 110.1029
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_baseline_bdt_discr_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# WJets 25388.0621948 13826.0
# diboson 704.409544796 5251.0
# tWchan 1296.66388482 4007.0
# tchan 7961.00072098 89583.0
# DYJets 1699.26124406 275.0
# TTJets 21961.7482702 388244.0
# qcd 835.893638611 305.0
# schan 428.817650348 2003.0
# MC: 60275.86 Data: 61241.00

# %%
h = pd("bdt_discr", "2j1t_baseline", "ele", rebin=3, legend_pos='top-right', legend_nudge_x=-0.065, log=True, max_bin_mult_log=1000)
h.process_scale_factor = scale_factors('ele', False)
#h.systematics_shapeonly = False
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['unclustereden', 'wjets_mg_flavour_shape_weight', 'qcd_yield', 'electron_triggerweight', 'wjets_mg_flavour_flat_weight', 'ttbar_scale', 'pu_weight', 'b_weight_nominal_bc', 'qcd_iso', 'b_weight_nominal_l', 'top_pt', 'lepton_weight_shape', 'res', 'electron_idweight', 'tchan_scale', 'mass', 'en']
# INFO:plots.syst_band] Systematic mass, 447.8282
# INFO:plots.syst_band] Systematic top_pt, 248.7132
# INFO:plots.syst_band] Systematic en, 208.1386
# INFO:plots.syst_band] Systematic res, 208.1310
# INFO:plots.syst_band] Systematic ttbar_scale, 116.6569
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 112.9594
# INFO:plots.syst_band] Systematic tchan_scale, 83.3141
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_baseline_bdt_discr_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# WJets 15911.486124 8240.0
# diboson 515.583806217 3351.0
# tWchan 848.272939801 2723.0
# qcd 1189.65475082 381.0
# tchan 3742.93958855 51650.0
# DYJets 857.897720264 131.0
# TTJets 15869.1454538 304703.0
# schan 241.24763231 1185.0
# MC: 39176.23 Data: 39413.00

# %%
h = pd("met", "2j1t_baseline_nomet", "mu", rebin=1, legend_pos='top-right', legend_nudge_x=-0.05, log=False)
h.process_scale_factor = scale_factors('mu', False, 0)
h.systematics_shapeonly = True
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'muon_triggerweight', 'en', 'muon_isoweight', 'qcd_yield', 'ttbar_scale', 'wjets_mg_flavour_shape_weight', 'mass', 'res', 'unclustereden', 'top_pt', 'b_weight_nominal_l', 'lepton_weight_shape', 'tchan_scale', 'b_weight_nominal_bc', 'muon_idweight', 'pu_weight']
# INFO:plots.syst_band] Systematic qcd_iso, 348.9908
# INFO:plots.syst_band] Systematic mass, 346.2154
# INFO:plots.syst_band] Systematic res, 316.5478
# INFO:plots.syst_band] Systematic unclustereden, 283.7529
# INFO:plots.syst_band] Systematic en, 273.5871
# INFO:plots.syst_band] Systematic tchan_scale, 246.7140
# INFO:plots.syst_band] Systematic ttbar_scale, 207.2582
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_baseline_nomet_met_mu.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 1079.0186978 8751.0
# DYJets 4792.85458946 761.0
# tchan 11348.872567 127871.0
# qcd 9080.3854928 1815.0
# WJets 37252.4082668 20360.0
# TTJets 31599.4546483 549653.0
# tWchan 1812.29543793 5610.0
# schan 611.589224942 2856.0
# MC: 97576.88 Data: 98857.00

# %%
h = pd("met", "2j1t_baseline_nomet", "ele", rebin=1, legend_pos='top-right', legend_nudge_x=-0.05, log=False)
h.process_scale_factor = scale_factors('ele', False, 0)
h.systematics_shapeonly = True
c, hists = data_mc_plot(h)
save_and_show(c)
# Out:
# INFO:plots.syst_band] Considering systematics ['wjets_mg_flavour_flat_weight', 'qcd_iso', 'res', 'en', 'electron_idweight', 'tchan_scale', 'ttbar_scale', 'wjets_mg_flavour_shape_weight', 'unclustereden', 'top_pt', 'b_weight_nominal_l', 'mass', 'electron_triggerweight', 'b_weight_nominal_bc', 'qcd_yield', 'lepton_weight_shape', 'pu_weight']
# INFO:plots.syst_band] Systematic qcd_iso, 283.3310
# INFO:plots.syst_band] Systematic res, 263.9639
# INFO:plots.syst_band] Systematic en, 256.0349
# INFO:plots.syst_band] Systematic mass, 236.0147
# INFO:plots.syst_band] Systematic unclustereden, 213.7341
# INFO:plots.syst_band] Systematic wjets_mg_flavour_flat_weight, 152.1295
# INFO:plots.syst_band] Systematic ttbar_scale, 148.9079
# WARNING:ROOT.TROOT.Append] Replacing existing TH1: 0line (Potential memory leak).
# INFO:ROOT.TCanvas.Print] pdf file out/plots/2j1t_baseline_nomet_met_ele.pdf has been created
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# diboson 1054.51212674 8616.0
# tchan 7398.61669477 100415.0
# qcd 12934.7666168 3455.0
# DYJets 8175.96529764 1182.0
# WJets 35361.4618263 17697.0
# TTJets 25860.8136393 465096.0
# tWchan 1448.31930665 4646.0
# schan 469.548152814 2285.0
# MC: 92704.00 Data: 90732.00

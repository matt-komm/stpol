# %%
from plots.common.sample import Sample
from plots.common.cuts import Cuts
from plots.common.mpl_hists import ipy_show_canv
from plots.common.tdrstyle import tdrstyle
import ROOT
import glob
import math
import numpy as np
ROOT.gROOT.SetBatch(True)

# %%
def find_samples(path, fnrule):
    import os, fnmatch
    out = []
    for root, dirs, items in os.walk(path):
        for it in items:
            p = os.path.join(root, it)
            if fnmatch.fnmatch(p, fnrule):
                out.append(p)
    return out
# Out:
#   File "<ipython-input-27-a23fb5a78058>", line 4
#     for it in items:
#                     ^
# IndentationError: expected an indented block

# %%
samples = dict()
samps = ["TTJets_FullLept", "TTJets_SemiLept", "T_t_ToLeptons", "Tbar_t_ToLeptons"]
basepath = "data/Aug4_0eb863_full/mu"
for s in samps:
    samples[s] = Sample.fromFile(basepath + "/mc/iso/nominal/Jul15/%s.root" % s)
for s in glob.glob(basepath + "/data/iso/*.root"):
    samp = Sample.fromFile(s)
    samples[samp.name] = samp
print "Loaded %d samples" % len(samples)
samples
# Out:
# Loaded 8 samples
# {'SingleMu1': <Sample(SingleMu1, data/Aug4_0eb863_full/mu/data/iso/SingleMu1.root)>,
#  'SingleMu2': <Sample(SingleMu2, data/Aug4_0eb863_full/mu/data/iso/SingleMu2.root)>,
#  'SingleMu3': <Sample(SingleMu3, data/Aug4_0eb863_full/mu/data/iso/SingleMu3.root)>,
#  'SingleMu_miss': <Sample(SingleMu_miss, data/Aug4_0eb863_full/mu/data/iso/SingleMu_miss.root)>,
#  'TTJets_FullLept': <Sample(TTJets_FullLept, data/Aug4_0eb863_full/mu/mc/iso/nominal/Jul15/TTJets_FullLept.root)>,
#  'TTJets_SemiLept': <Sample(TTJets_SemiLept, data/Aug4_0eb863_full/mu/mc/iso/nominal/Jul15/TTJets_SemiLept.root)>,
#  'T_t_ToLeptons': <Sample(T_t_ToLeptons, data/Aug4_0eb863_full/mu/mc/iso/nominal/Jul15/T_t_ToLeptons.root)>,
#  'Tbar_t_ToLeptons': <Sample(Tbar_t_ToLeptons, data/Aug4_0eb863_full/mu/mc/iso/nominal/Jul15/Tbar_t_ToLeptons.root)>}

# %%
hists = dict()
draw = lambda x: x.drawHistogram2D("cos_theta", "mu_eta",
        str(Cuts.lepton("mu")*Cuts.metmt("mu") * Cuts.hlt("mu")*Cuts.n_jets(2)*Cuts.n_tags(1)*Cuts.mva_wp("mu")),
        binning_x=[10, -1, 1], binning_y=[10, -2.5, 2.5]
)
for k, v in samples.items():
    hists[k] = draw(v)
    if v.isMC:
        hists[k].Scale(v.lumiScaleFactor(20000))
print "Projected %d histograms" % len(hists)
# Out:
# Projected 8 histograms

# %%
sample_groups = {
    "ttbar": hists["TTJets_SemiLept"]+hists["TTJets_FullLept"],
    "tchan": hists["T_t_ToLeptons"]+hists["Tbar_t_ToLeptons"],
    "data": sum([h for k, h in hists.items() if k.startswith("Single")])
}

# %%
#hi = hists["T_t_ToLeptons"]+hists["Tbar_t_ToLeptons"]
#hi = hists["T_t_ToLeptons"]+hists["Tbar_t_ToLeptons"]

def draw_process(name):
    hi = sample_groups[name]
    
    tdrstyle()
    c = ROOT.TCanvas()
    hi.GetXaxis().SetTitle("cos #theta")
    hi.GetYaxis().SetTitle("#eta_{lepton}")
    hi.Draw("COL")
    hi.SetTitle(name)
    ROOT.gStyle.SetPalette(55)
    #c.SetLogz()
    print "N=%d" % hi.GetEntries(), "int=%.2f" % hi.Integral()
    print "corr=%.5f" % hi.GetCorrelationFactor(), "cov=%.5f" % hi.GetCovariance()
    return ipy_show_canv(c), hi

# %% [markdown]
# # Analyzing the correlations

# %% [markdown]
# ## Data

# %%
pic, hi = draw_process("data")
pic
# Out:
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# N=4864 int=4864.00
# corr=0.02220 cov=0.01164

# %% [markdown]
# ## TTBar

# %%
draw_process("ttbar")
# Out:
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# N=8995 int=668.45
# corr=0.03516 cov=0.01968

# %% [markdown]
# ## signal (t-channel)

# %%
draw_process("tchan")
# Out:
# INFO:ROOT.TCanvas.Print] png file temp.png has been created
# N=28430 int=2844.51
# corr=0.01084 cov=0.00454

# %%
sgs = [
    ("tchan", ["T_t_ToLeptons", "Tbar_t_ToLeptons"]),
    ("ttbar", ["TTJets_FullLept", "TTJets_SemiLept"]),
    ("data", ["SingleMu1", "SingleMu2", "SingleMu3", "SingleMu_miss"])
]
dpoints = dict()
for sn, slist in sgs:
    x = []
    y = []
    errs = []
    print sn
    for cut in np.linspace(-0.8, 0.5, 20):
        draw = lambda x: x.drawHistogram2D("cos_theta", "mu_eta",
            str(Cuts.lepton("mu")*Cuts.metmt("mu") * Cuts.hlt("mu")*Cuts.n_jets(2)*Cuts.n_tags(1)*Cuts.mva_wp("mu", cut)),
            binning_x=[10, -1, 1], binning_y=[10, -2.5, 2.5]
        )
        hists = [draw(samples[k]) for k in slist]
        hi = reduce(lambda x,y: x+y, hists)
        rho = hi.GetCorrelationFactor()
        err_rho = (1-rho**2)**2/math.sqrt(hi.GetEntries()-1)
        x.append(cut)
        y.append(rho)
        errs.append(err_rho)
        print cut, rho, err_rho
    dpoints[sn] = x, y, errs
# Out:
# tchan
# -0.8
#  0.00478633716732 0.00335321066439
# -0.731578947368
#  0.00582122999233 0.00354069798259
# -0.663157894737
#  0.0072668889348 0.0037263087371
# -0.594736842105
#  0.0111216122153 0.0039110768147
# -0.526315789474
#  0.0108431618969 0.00407365483792
# -0.457894736842
#  0.0110618608239 0.0042325291688
# -0.389473684211
#  0.0100524720583 0.00440234611401
# -0.321052631579
#  0.00662886365265 0.00459682340838
# -0.252631578947
#  0.00469670502246 0.00480525935091
# -0.184210526316
#  0.0061854546691 0.00502607392858
# -0.115789473684
#  0.00924745032354 0.00525317080632
# -0.0473684210526
#  0.0124339869024 0.00549471466836
# 0.0210526315789
#  0.0110590265208 0.0057671905253
# 0.0894736842105
#  0.011536975303 0.00606277975333
# 0.157894736842
#  0.01128716123 0.00640612292223
# 0.226315789474
#  0.0093956266811 0.00680593092651
# 0.294736842105
#  0.016495391315 0.00727651973452
# 0.363157894737
#  0.0183083458211 0.00786532514549
# 0.431578947368
#  0.02035358242 0.00861707143585
# 0.5
#  0.01544054736 0.00958910400872
# ttbar
# -0.8
#  0.00638098868728 0.00219886626427
# -0.731578947368
#  0.0106264912034 0.00268542150714
# -0.663157894737
#  0.0111615784495 0.00319650755052
# -0.594736842105
#  0.0111156455571 0.00374195289921
# -0.526315789474
#  0.0113433587768 0.00423673028223
# -0.457894736842
#  0.0159568159802 0.0047204120617
# -0.389473684211
#  0.0184133095824 0.00524190436289
# -0.321052631579
#  0.0128440231701 0.00585936449156
# -0.252631578947
#  0.00502412368218 0.0065521526551
# -0.184210526316
#  0.00640077613553 0.00728722733962
# -0.115789473684
#  0.00858084126933 0.0080704174513
# -0.0473684210526
#  0.0109702430792 0.00892393292864
# 0.0210526315789
#  0.0225621213094 0.00991719613822
# 0.0894736842105
#  0.0354617287875 0.0109993109948
# 0.157894736842
#  0.0372430858919 0.0123077034741
# 0.226315789474
#  0.0314943436263 0.0139613551376
# 0.294736842105
#  0.0435241742968 0.0158388951291
# 0.363157894737
#  0.0338293880021 0.0184477098138
# 0.431578947368
#  0.0312278951656 0.0216101174454
# 0.5
#  0.0413882114338 0.0261443613847
# data
# -0.8
#  0.00683489867338 0.0050169973156
# -0.731578947368
#  0.00299023479305 0.00581827627002
# -0.663157894737
#  0.00598622754396 0.00659777999472
# -0.594736842105
#  0.00497892736089 0.0073539683502
# -0.526315789474
#  0.00383602620434 0.008018517747
# -0.457894736842
#  0.0110014777382 0.00861156611298
# -0.389473684211
#  0.0125701180805 0.00924682511282
# -0.321052631579
#  0.00654950125923 0.00997572662244
# -0.252631578947
#  0.00352362649353 0.0107387720175
# -0.184210526316
#  0.00826585412611 0.0115216407181
# -0.115789473684
#  0.00904400412625 0.0122497334172
# -0.0473684210526
#  0.0151392910823 0.0130118213209
# 0.0210526315789
#  0.0213029927491 0.0138151271133
# 0.0894736842105
#  0.0285220602881 0.0147426679236
# 0.157894736842
#  0.0339165029698 0.0158027116065
# 0.226315789474
#  0.0349489526443 0.0169639091166
# 0.294736842105
#  0.0313017198523 0.0182673846488
# 0.363157894737
#  0.0280529393662 0.02002065524
# 0.431578947368
#  0.0343396628416 0.0221370722757
# 0.5
#  0.0246805842346 0.024715970134

# %%
from plots.common.mpl_tdrstyle import plt
# %matplotlib inline

fig = plt.figure(
    figsize=(10,10)
)

ax = plt.axes()
ax.set_title("Correlation dependence on the BDT WP, muon channel")
ax.grid(which="both")
ax.set_ylabel(r"correlation factor $\rho(\cos \theta, \eta_{lepton})$", fontsize=16)
ax.set_xlabel("BDT cut value", fontsize=16)
ax.set_ylim(0, 0.1)
ax.axvline(Cuts.mva_wps['bdt']['mu']['loose'], color="black", label="BDT loose WP", linewidth=2, ls='--')
dit = dpoints.items()
legit = []
for sn, args in dit:
    ax.errorbar(*args, label=sn)
    legit.append(sn)
leg = ax.legend()
